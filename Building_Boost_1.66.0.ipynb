# %%
# %%time
# !wget -nc https://dl.bintray.com/boostorg/release/1.66.0/source/boost_1_66_0.tar.gz
# Out:
# --2021-03-06 04:56:33--  https://dl.bintray.com/boostorg/release/1.66.0/source/boost_1_66_0.tar.gz
# Resolving dl.bintray.com (dl.bintray.com)... 52.88.129.62, 52.27.102.247, 54.186.11.108, ...
# Connecting to dl.bintray.com (dl.bintray.com)|52.88.129.62|:443... connected.
# HTTP request sent, awaiting response... 302
# Location: https://d29vzk4ow07wi7.cloudfront.net/bd0df411efd9a585e5a2212275f8762079fed8842264954675a4fddc46cfcf60?response-content-disposition=attachment%3Bfilename%3D%22boost_1_66_0.tar.gz%22&Policy=...&Signature=QPQ~Ji~lx81U9hygieJXSq0VHEFX1XCSOAPk6vBUpsm-kCc675sunnxsHUvwdexN47QAZrZGgivUNocw0xefsUqF-LEvL9vVyNt85tXMiWzYVWnUNursv2r8TWyM7BZxgVODdTCfCNbe-N9w781EYmNMv55h0fm-SKp5A1pbVPI3men659Vf4JN53c-YcyrPHL34~d0rOj3is1OODaW7ObdBxpLK-GdYbcs94pythh1P~bCd~jgXTKACFfA7mghXxBAso7UCKm5tNbdsFH-H~nDaqexDRvIapBqtMXftuzT2nQv4eF1dQie57QShpzNaCaXVKGGjLsg4ZPnI9hOluw__&Key-Pair-Id=APKAIFKFWOMXM2UMTSFA [following]
# ...

# %%
# !dpkg -s libboost-dev | grep Version
# Out:
# Version: 1.65.1.0ubuntu1

# %%
# !dpkg -s libboost-dev | grep Version
# Out:
# Version: 1.65.1.0ubuntu1

# %%
# %%time
#!tar xzvf boost_1_66_0.tar.gz
# !ls
# %cd boost_1_66_0/
# !ls
# Out:
# arlib			     osm-routing-bgl	     pgRouting_Demo_bak
# boost_1_66_0		     pgrouting-2.6.0	     PostGIS_demo
# boost_1_66_0.tar.gz	     pgrouting-2.6.0.tar.gz  road
# build			     pgrouting-2.6.3	     Sedona_demo
# Building_Boost_1.66.0.ipynb  pgrouting-2.6.3.tar.gz  WebGIS_Service_demo
# build_pgrouting.ipynb	     pgRouting_Demo
# /home/jovyan/work/deepgeo/boost_1_66_0
# b2	boost-build.jam  bootstrap.bat	index.htm   libs		rst.css
# bin.v2	boostcpp.jam	 bootstrap.log	index.html  LICENSE_1_0.txt	stage
# bjam	boost.css	 bootstrap.sh	INSTALL     more		status
# boost	boost.png	 doc		Jamroot     project-config.jam	tools
# CPU times: user 8.76 ms, sys: 14.3 ms, total: 23 ms
# Wall time: 2.63 s

# %%
# !ls
# Out:
# boost		 boost.png	index.htm   libs	     status
# boost-build.jam  bootstrap.bat	index.html  LICENSE_1_0.txt  tools
# boostcpp.jam	 bootstrap.sh	INSTALL     more
# boost.css	 doc		Jamroot     rst.css

# %%
# %%time
# !./bootstrap.sh --prefix=/opt/conda/
#/usr/local/
# Out:
# Building Boost.Build engine with toolset gcc... tools/build/src/engine/bin.linuxx86_64/b2
# Detecting Python version... 3.7
# Detecting Python root... /opt/conda
# Unicode/ICU support for Boost.Regex?... /usr
# Backing up existing Boost.Build configuration in project-config.jam.1
# Generating Boost.Build configuration in project-config.jam...
#
# Bootstrapping is done. To build, run:
#
#     ./b2
#
# To adjust configuration, edit 'project-config.jam'.
# Further information:
#
#    - Command line help:
#      ./b2 --help
#
#    - Getting started guide:
#      http://www.boost.org/more/getting_started/unix-variants.html
#
#    - Boost.Build documentation:
#      http://www.boost.org/build/doc/html/index.html
#
# CPU times: user 332 ms, sys: 141 ms, total: 472 ms
# Wall time: 13.5 s

# %%
# !./b2 --help
# Out:
# Boost.Build 2015.07-git
#
# Project-specific help:
#
#   Project has jamfile at Jamroot
#
# Usage:
#
#   b2 [options] [properties] [install|stage]
#
#   Builds and installs Boost.
#
# Targets and Related Options:
#
#   install                 Install headers and compiled library files to the
#   =======                 configured locations (below).
#
#   --prefix=<PREFIX>       Install architecture independent files here.
#                           Default; C:\Boost on Win32
#                           Default; /usr/local on Unix. Linux, etc.
#
#   --exec-prefix=<EPREFIX> Install architecture dependent files here.
#                           Default; <PREFIX>
#
#   --libdir=<DIR>          Install library files here.
#                           Default; <EPREFIX>/lib
#
#   --includedir=<HDRDIR>   Install header files here.
#                           Default; <PREFIX>/include
#
#   stage                   Build and install only compiled library files to the
# ...

# %%
# %%time
# !./b2 -j8 variant=release link=shared threading=multi runtime-link=shared
# Out:
# Performing configuration checks
#
#     - 32-bit                   : no  (cached)
#     - 64-bit                   : yes (cached)
#     - arm                      : no  (cached)
#     - mips1                    : no  (cached)
#     - power                    : no  (cached)
#     - sparc                    : no  (cached)
#     - x86                      : yes (cached)
#
# Building the Boost C++ Libraries.
#
#
#     - symlinks supported       : yes (cached)
#     - C++11 mutex              : yes (cached)
#     - lockfree boost::atomic_flag : yes (cached)
#     - Boost.Config Feature Check: cxx11_auto_declarations : yes (cached)
#     - Boost.Config Feature Check: cxx11_constexpr : yes (cached)
#     - Boost.Config Feature Check: cxx11_defaulted_functions : yes (cached)
#     - Boost.Config Feature Check: cxx11_final : yes (cached)
#     - Boost.Config Feature Check: cxx11_hdr_mutex : yes (cached)
#     - Boost.Config Feature Check: cxx11_hdr_regex : yes (cached)
# ...

# %%
# %%time

# !./b2 -j8 install
# Out:
# Performing configuration checks
#
#     - 32-bit                   : no  (cached)
#     - 64-bit                   : yes (cached)
#     - arm                      : no  (cached)
#     - mips1                    : no  (cached)
#     - power                    : no  (cached)
#     - sparc                    : no  (cached)
#     - x86                      : yes (cached)
#     - symlinks supported       : yes (cached)
#     - C++11 mutex              : yes (cached)
#     - lockfree boost::atomic_flag : yes (cached)
#     - Boost.Config Feature Check: cxx11_auto_declarations : yes (cached)
#     - Boost.Config Feature Check: cxx11_constexpr : yes (cached)
#     - Boost.Config Feature Check: cxx11_defaulted_functions : yes (cached)
#     - Boost.Config Feature Check: cxx11_final : yes (cached)
#     - Boost.Config Feature Check: cxx11_hdr_mutex : yes (cached)
#     - Boost.Config Feature Check: cxx11_hdr_regex : yes (cached)
# ...

# %%
# %%time
#%cd ../../../../
# !ls
# %cd pgrouting-2.6.3
# !ls
# Out:
# --2021-03-06 05:31:29--  https://github.com/pgRouting/pgrouting/archive/v2.6.3.tar.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/pgRouting/pgrouting/tar.gz/v2.6.3 [following]
# --2021-03-06 05:31:30--  https://codeload.github.com/pgRouting/pgrouting/tar.gz/v2.6.3
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘pgrouting-2.6.3.tar.gz’
#
# pgrouting-2.6.3.tar     [   <=>              ]   5.79M  11.8MB/s    in 0.5s
#
# 2021-03-06 05:31:30 (11.8 MB/s) - ‘pgrouting-2.6.3.tar.gz’ saved [6066698]
#
# CPU times: user 40 ms, sys: 27 ms, total: 66.9 ms
# Wall time: 2.22 s
